# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = '../../Data/training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.
# d:\anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# d:\anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\anaconda3\envs\keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From d:\anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From d:\anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From d:\anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From d:\anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From d:\anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From d:\anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From d:\anaconda3\envs\keras\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From d:\anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 0.0065 - val_loss: 0.0022
#
# Epoch 00001: val_loss improved from inf to 0.00219, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 0.0016 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00219 to 0.00195, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 0.0013 - val_loss: 0.0020
#
# Epoch 00003: val_loss did not improve from 0.00195
# Epoch 4/150
# 1712/1712 [==============================] - 0s 156us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00195 to 0.00190, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00190
# Epoch 6/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00190 to 0.00180, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 9.1511e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00180 to 0.00173, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 8.1731e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00173 to 0.00163, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 7.2228e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00163 to 0.00153, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 6.4955e-04 - val_loss: 0.0014
#
# Epoch 00010: val_loss improved from 0.00153 to 0.00139, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 5.9577e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00139 to 0.00124, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 5.5044e-04 - val_loss: 0.0012
#
# Epoch 00012: val_loss improved from 0.00124 to 0.00120, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 5.0137e-04 - val_loss: 0.0012
#
# Epoch 00013: val_loss improved from 0.00120 to 0.00117, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 4.6662e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00117 to 0.00108, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 4.3716e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss improved from 0.00108 to 0.00107, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 4.3131e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss improved from 0.00107 to 0.00101, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 155us/step - loss: 4.1427e-04 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00101
# Epoch 18/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 3.9265e-04 - val_loss: 9.8137e-04
#
# Epoch 00018: val_loss improved from 0.00101 to 0.00098, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 3.6068e-04 - val_loss: 9.7785e-04
#
# Epoch 00019: val_loss improved from 0.00098 to 0.00098, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 3.4398e-04 - val_loss: 9.7012e-04
#
# Epoch 00020: val_loss improved from 0.00098 to 0.00097, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 3.3248e-04 - val_loss: 9.2232e-04
#
# Epoch 00021: val_loss improved from 0.00097 to 0.00092, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 3.2521e-04 - val_loss: 9.1812e-04
#
# Epoch 00022: val_loss improved from 0.00092 to 0.00092, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 0s 158us/step - loss: 3.1660e-04 - val_loss: 8.6480e-04
#
# Epoch 00023: val_loss improved from 0.00092 to 0.00086, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 0s 158us/step - loss: 2.9687e-04 - val_loss: 9.6910e-04
#
# Epoch 00024: val_loss did not improve from 0.00086
# Epoch 25/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 2.9197e-04 - val_loss: 9.2603e-04
#
# Epoch 00025: val_loss did not improve from 0.00086
# Epoch 26/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 2.8792e-04 - val_loss: 8.5808e-04
#
# Epoch 00026: val_loss improved from 0.00086 to 0.00086, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 2.8076e-04 - val_loss: 8.5916e-04
#
# Epoch 00027: val_loss did not improve from 0.00086
# Epoch 28/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 2.7673e-04 - val_loss: 8.3447e-04
#
# Epoch 00028: val_loss improved from 0.00086 to 0.00083, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 2.6349e-04 - val_loss: 8.1063e-04
#
# Epoch 00029: val_loss improved from 0.00083 to 0.00081, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 0s 156us/step - loss: 2.6749e-04 - val_loss: 8.6333e-04
#
# Epoch 00030: val_loss did not improve from 0.00081
# Epoch 31/150
# 1712/1712 [==============================] - 0s 157us/step - loss: 2.6044e-04 - val_loss: 8.4579e-04
#
# Epoch 00031: val_loss did not improve from 0.00081
# Epoch 32/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 2.4867e-04 - val_loss: 8.0408e-04
#
# Epoch 00032: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 2.4423e-04 - val_loss: 7.9035e-04
#
# Epoch 00033: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 2.4043e-04 - val_loss: 7.8976e-04
#
# Epoch 00034: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 2.3689e-04 - val_loss: 8.1001e-04
#
# Epoch 00035: val_loss did not improve from 0.00079
# Epoch 36/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 2.2934e-04 - val_loss: 8.1068e-04
#
# Epoch 00036: val_loss did not improve from 0.00079
# Epoch 37/150
# 1712/1712 [==============================] - 0s 155us/step - loss: 2.2540e-04 - val_loss: 8.3195e-04
#
# Epoch 00037: val_loss did not improve from 0.00079
# Epoch 38/150
# 1712/1712 [==============================] - 0s 157us/step - loss: 2.1950e-04 - val_loss: 8.0113e-04
#
# Epoch 00038: val_loss did not improve from 0.00079
# Epoch 39/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 2.1478e-04 - val_loss: 8.0835e-04
#
# Epoch 00039: val_loss did not improve from 0.00079
# Epoch 40/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 2.1523e-04 - val_loss: 7.8053e-04
#
# Epoch 00040: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 2.0885e-04 - val_loss: 7.9784e-04
#
# Epoch 00041: val_loss did not improve from 0.00078
# Epoch 42/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 2.0677e-04 - val_loss: 8.2729e-04
#
# Epoch 00042: val_loss did not improve from 0.00078
# Epoch 43/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 2.0861e-04 - val_loss: 8.2063e-04
#
# Epoch 00043: val_loss did not improve from 0.00078
# Epoch 44/150
# 1712/1712 [==============================] - 0s 157us/step - loss: 2.0256e-04 - val_loss: 7.7425e-04
#
# Epoch 00044: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 0s 158us/step - loss: 2.0231e-04 - val_loss: 8.1944e-04
#
# Epoch 00045: val_loss did not improve from 0.00077
# Epoch 46/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.9486e-04 - val_loss: 7.7837e-04
#
# Epoch 00046: val_loss did not improve from 0.00077
# Epoch 47/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 1.9295e-04 - val_loss: 7.6439e-04
#
# Epoch 00047: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 48/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 1.8998e-04 - val_loss: 8.0740e-04
#
# Epoch 00048: val_loss did not improve from 0.00076
# Epoch 49/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.8745e-04 - val_loss: 7.6092e-04
#
# Epoch 00049: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 1.8936e-04 - val_loss: 7.5828e-04
#
# Epoch 00050: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 0s 156us/step - loss: 1.8490e-04 - val_loss: 8.1659e-04
#
# Epoch 00051: val_loss did not improve from 0.00076
# Epoch 52/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.7859e-04 - val_loss: 7.7674e-04
#
# Epoch 00052: val_loss did not improve from 0.00076
# Epoch 53/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.7437e-04 - val_loss: 7.7389e-04
#
# Epoch 00053: val_loss did not improve from 0.00076
# Epoch 54/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 1.7417e-04 - val_loss: 7.6240e-04
#
# Epoch 00054: val_loss did not improve from 0.00076
# Epoch 55/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.7459e-04 - val_loss: 7.5069e-04
#
# Epoch 00055: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 56/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.7395e-04 - val_loss: 7.5792e-04
#
# Epoch 00056: val_loss did not improve from 0.00075
# Epoch 57/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.7213e-04 - val_loss: 8.0907e-04
#
# Epoch 00057: val_loss did not improve from 0.00075
# Epoch 58/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.6762e-04 - val_loss: 8.2133e-04
#
# Epoch 00058: val_loss did not improve from 0.00075
# Epoch 59/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.7469e-04 - val_loss: 7.7132e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.6595e-04 - val_loss: 7.7398e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 1.5995e-04 - val_loss: 7.7849e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.5719e-04 - val_loss: 7.7143e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.5669e-04 - val_loss: 7.7428e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.5495e-04 - val_loss: 7.7877e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.5571e-04 - val_loss: 8.1705e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.6025e-04 - val_loss: 7.7828e-04
#
# Epoch 00066: val_loss did not improve from 0.00075
# Epoch 67/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 1.5261e-04 - val_loss: 7.9634e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 1.4960e-04 - val_loss: 8.1197e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.4751e-04 - val_loss: 7.9798e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 1.4609e-04 - val_loss: 7.6946e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 1.5007e-04 - val_loss: 7.8290e-04
#
# Epoch 00071: val_loss did not improve from 0.00075
# Epoch 72/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.4787e-04 - val_loss: 7.7699e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/150
# 1712/1712 [==============================] - 0s 157us/step - loss: 1.4474e-04 - val_loss: 7.7176e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.4458e-04 - val_loss: 7.4875e-04
#
# Epoch 00074: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 75/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.4241e-04 - val_loss: 7.9176e-04
#
# Epoch 00075: val_loss did not improve from 0.00075
# Epoch 76/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.3498e-04 - val_loss: 7.7263e-04
#
# Epoch 00076: val_loss did not improve from 0.00075
# Epoch 77/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.4192e-04 - val_loss: 8.0853e-04
#
# Epoch 00077: val_loss did not improve from 0.00075
# Epoch 78/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 1.4717e-04 - val_loss: 7.4498e-04
#
# Epoch 00078: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 79/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 1.3919e-04 - val_loss: 8.0573e-04
#
# Epoch 00079: val_loss did not improve from 0.00074
# Epoch 80/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.3904e-04 - val_loss: 7.6800e-04
#
# Epoch 00080: val_loss did not improve from 0.00074
# Epoch 81/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 1.3771e-04 - val_loss: 7.4377e-04
#
# Epoch 00081: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 82/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.3062e-04 - val_loss: 7.9744e-04
#
# Epoch 00082: val_loss did not improve from 0.00074
# Epoch 83/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.3138e-04 - val_loss: 8.2095e-04
#
# Epoch 00083: val_loss did not improve from 0.00074
# Epoch 84/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 1.2866e-04 - val_loss: 7.4387e-04
#
# Epoch 00084: val_loss did not improve from 0.00074
# Epoch 85/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.2689e-04 - val_loss: 7.7002e-04
#
# Epoch 00085: val_loss did not improve from 0.00074
# Epoch 86/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.2795e-04 - val_loss: 7.7994e-04
#
# Epoch 00086: val_loss did not improve from 0.00074
# Epoch 87/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.2753e-04 - val_loss: 7.7335e-04
#
# Epoch 00087: val_loss did not improve from 0.00074
# Epoch 88/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.2739e-04 - val_loss: 7.7559e-04
#
# Epoch 00088: val_loss did not improve from 0.00074
# Epoch 89/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 1.2403e-04 - val_loss: 7.8513e-04
#
# Epoch 00089: val_loss did not improve from 0.00074
# Epoch 90/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.2930e-04 - val_loss: 7.4877e-04
#
# Epoch 00090: val_loss did not improve from 0.00074
# Epoch 91/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.2082e-04 - val_loss: 7.6202e-04
#
# Epoch 00091: val_loss did not improve from 0.00074
# Epoch 92/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.1748e-04 - val_loss: 7.6771e-04
#
# Epoch 00092: val_loss did not improve from 0.00074
# Epoch 93/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 1.2110e-04 - val_loss: 7.6940e-04
#
# Epoch 00093: val_loss did not improve from 0.00074
# Epoch 94/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.2191e-04 - val_loss: 7.5989e-04
#
# Epoch 00094: val_loss did not improve from 0.00074
# Epoch 95/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.1954e-04 - val_loss: 7.6833e-04
#
# Epoch 00095: val_loss did not improve from 0.00074
# Epoch 96/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 1.1453e-04 - val_loss: 7.6563e-04
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.1970e-04 - val_loss: 7.6960e-04
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 1.1821e-04 - val_loss: 7.6992e-04
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.1496e-04 - val_loss: 7.5314e-04
#
# Epoch 00099: val_loss did not improve from 0.00074
# Epoch 100/150
# 1712/1712 [==============================] - 0s 153us/step - loss: 1.1298e-04 - val_loss: 7.5293e-04
#
# Epoch 00100: val_loss did not improve from 0.00074
# Epoch 101/150
# 1712/1712 [==============================] - 0s 153us/step - loss: 1.1465e-04 - val_loss: 7.9660e-04
#
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 1712/1712 [==============================] - 0s 154us/step - loss: 1.1716e-04 - val_loss: 7.6276e-04
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 1712/1712 [==============================] - 0s 155us/step - loss: 1.1371e-04 - val_loss: 7.4781e-04
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 1712/1712 [==============================] - 0s 155us/step - loss: 1.1206e-04 - val_loss: 7.5584e-04
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 1.1178e-04 - val_loss: 7.7413e-04
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 1.1302e-04 - val_loss: 7.9296e-04
#
# Epoch 00106: val_loss did not improve from 0.00074
# Epoch 107/150
# 1712/1712 [==============================] - 0s 155us/step - loss: 1.0475e-04 - val_loss: 7.7656e-04
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 1712/1712 [==============================] - 0s 158us/step - loss: 1.0826e-04 - val_loss: 7.4594e-04
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 1712/1712 [==============================] - 0s 156us/step - loss: 1.1055e-04 - val_loss: 7.7314e-04
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 1712/1712 [==============================] - 0s 157us/step - loss: 1.0614e-04 - val_loss: 7.4468e-04
#
# Epoch 00110: val_loss did not improve from 0.00074
# Epoch 111/150
# 1712/1712 [==============================] - 0s 158us/step - loss: 1.0903e-04 - val_loss: 7.7895e-04
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.0726e-04 - val_loss: 7.6980e-04
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 1712/1712 [==============================] - 0s 157us/step - loss: 1.0340e-04 - val_loss: 7.8011e-04
#
# Epoch 00113: val_loss did not improve from 0.00074
# Epoch 114/150
# 1712/1712 [==============================] - 0s 155us/step - loss: 1.0553e-04 - val_loss: 7.6228e-04
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 1712/1712 [==============================] - 0s 153us/step - loss: 1.0235e-04 - val_loss: 7.8136e-04
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 1712/1712 [==============================] - 0s 154us/step - loss: 1.0649e-04 - val_loss: 7.7191e-04
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 1712/1712 [==============================] - 0s 154us/step - loss: 1.0372e-04 - val_loss: 7.8907e-04
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 1712/1712 [==============================] - 0s 154us/step - loss: 1.0441e-04 - val_loss: 7.6582e-04
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 1712/1712 [==============================] - 0s 157us/step - loss: 1.0455e-04 - val_loss: 7.8933e-04
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 1.0763e-04 - val_loss: 7.5771e-04
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 1.0436e-04 - val_loss: 7.7051e-04
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 1712/1712 [==============================] - 0s 155us/step - loss: 9.9913e-05 - val_loss: 7.3096e-04
#
# Epoch 00122: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 123/150
# 1712/1712 [==============================] - 0s 155us/step - loss: 1.0004e-04 - val_loss: 7.3904e-04
#
# Epoch 00123: val_loss did not improve from 0.00073
# Epoch 124/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 9.9470e-05 - val_loss: 7.3954e-04
#
# Epoch 00124: val_loss did not improve from 0.00073
# Epoch 125/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 9.9217e-05 - val_loss: 7.3269e-04
#
# Epoch 00125: val_loss did not improve from 0.00073
# Epoch 126/150
# 1712/1712 [==============================] - 0s 158us/step - loss: 9.6581e-05 - val_loss: 7.8259e-04
#
# Epoch 00126: val_loss did not improve from 0.00073
# Epoch 127/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 9.7477e-05 - val_loss: 7.2964e-04
#
# Epoch 00127: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 128/150
# 1712/1712 [==============================] - ETA: 0s - loss: 9.6459e-0 - 0s 168us/step - loss: 9.7703e-05 - val_loss: 7.3817e-04
#
# Epoch 00128: val_loss did not improve from 0.00073
# Epoch 129/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 9.3265e-05 - val_loss: 7.5071e-04
#
# Epoch 00129: val_loss did not improve from 0.00073
# Epoch 130/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 9.3796e-05 - val_loss: 7.8623e-04
#
# Epoch 00130: val_loss did not improve from 0.00073
# Epoch 131/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 9.8809e-05 - val_loss: 7.7225e-04
#
# Epoch 00131: val_loss did not improve from 0.00073
# Epoch 132/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 9.5512e-05 - val_loss: 7.7330e-04
#
# Epoch 00132: val_loss did not improve from 0.00073
# Epoch 133/150
# 1712/1712 [==============================] - 0s 157us/step - loss: 9.1812e-05 - val_loss: 7.9343e-04
#
# Epoch 00133: val_loss did not improve from 0.00073
# Epoch 134/150
# 1712/1712 [==============================] - 0s 157us/step - loss: 9.1568e-05 - val_loss: 7.8134e-04
#
# Epoch 00134: val_loss did not improve from 0.00073
# Epoch 135/150
# 1712/1712 [==============================] - 0s 155us/step - loss: 8.9735e-05 - val_loss: 7.5373e-04
#
# Epoch 00135: val_loss did not improve from 0.00073
# Epoch 136/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 8.9481e-05 - val_loss: 7.9374e-04
#
# Epoch 00136: val_loss did not improve from 0.00073
# Epoch 137/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 9.0735e-05 - val_loss: 7.5554e-04
#
# Epoch 00137: val_loss did not improve from 0.00073
# Epoch 138/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.0449e-05 - val_loss: 7.5836e-04
#
# Epoch 00138: val_loss did not improve from 0.00073
# Epoch 139/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 8.6716e-05 - val_loss: 7.7209e-04
#
# Epoch 00139: val_loss did not improve from 0.00073
# Epoch 140/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 8.7349e-05 - val_loss: 7.5653e-04
#
# Epoch 00140: val_loss did not improve from 0.00073
# Epoch 141/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 8.6609e-05 - val_loss: 7.7516e-04
#
# Epoch 00141: val_loss did not improve from 0.00073
# Epoch 142/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 8.5417e-05 - val_loss: 7.5187e-04
#
# Epoch 00142: val_loss did not improve from 0.00073
# Epoch 143/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 8.5038e-05 - val_loss: 7.8122e-04
#
# Epoch 00143: val_loss did not improve from 0.00073
# Epoch 144/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 8.8258e-05 - val_loss: 7.8296e-04
#
# Epoch 00144: val_loss did not improve from 0.00073
# Epoch 145/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 8.9070e-05 - val_loss: 7.5728e-04
#
# Epoch 00145: val_loss did not improve from 0.00073
# Epoch 146/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 9.3373e-05 - val_loss: 7.5335e-04
#
# Epoch 00146: val_loss did not improve from 0.00073
# Epoch 147/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 8.5691e-05 - val_loss: 7.5434e-04
#
# Epoch 00147: val_loss did not improve from 0.00073
# Epoch 148/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 8.6057e-05 - val_loss: 7.9852e-04
#
# Epoch 00148: val_loss did not improve from 0.00073
# Epoch 149/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 8.3742e-05 - val_loss: 7.6163e-04
#
# Epoch 00149: val_loss did not improve from 0.00073
# Epoch 150/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 8.4632e-05 - val_loss: 7.5828e-04
#
# Epoch 00150: val_loss did not improve from 0.00073

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = '../../Data/test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
